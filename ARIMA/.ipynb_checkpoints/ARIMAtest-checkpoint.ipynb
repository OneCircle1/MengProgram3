# %%
from statsmodels.tsa.stattools import acf, pacf

# %%
import statsmodels.tsa.stattools as ts

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
import pandas as pd
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
import math
import datetime

# %%
data = pd.read_csv('ge.us.txt', sep=",", header=0)
data.columns = ["Date", "Open", "High", "Low", "Close", "Volume", "OpenInt"]

# %%
dates = []
prices = []

# %%
data_dates = data.loc[:,"Date"]
data_open = data.loc[:, "Open"]

# %%
for date in data_dates:
#     dates.append([int(date.split('-')[2])])
    interval = datetime.datetime(int(date.split('-')[0]),int(date.split('-')[1]),int(date.split('-')[2])) - datetime.datetime(1962,1,2)
    dates.append([int(interval.days+1)])

for open_price in data_open:
    prices.append(float(open_price))

# %%
prices
# Out:
# [0.6277,
#  0.6201,
#  0.6201,
#  0.6122,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.6037,
#  0.5878,
#  0.5957,
#  0.6037,
#  0.6037,
#  0.5878,
#  0.6037,
#  0.5957,
#  0.5957,
#  0.6037,
#  0.6037,
#  0.6277,
#  0.6201,
#  0.6201,
#  0.6122,
#  0.6201,
#  0.6277,
#  0.6277,
#  0.6277,
#  0.6277,
#  0.6362,
#  0.6362,
#  0.6442,
#  0.6442,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6277,
#  0.6201,
#  0.6277,
#  0.6277,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6277,
#  0.6362,
#  0.6442,
#  0.652,
#  0.652,
#  0.652,
#  0.6442,
#  0.652,
#  0.652,
#  0.6442,
#  0.6442,
#  0.6442,
#  0.6442,
#  0.652,
#  0.6362,
#  0.6442,
#  0.652,
#  0.6442,
#  0.6362,
#  0.6362,
#  0.6277,
#  0.6277,
#  0.6362,
#  0.6362,
#  0.6277,
#  0.6201,
#  0.6122,
#  0.6122,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6122,
#  0.6122,
#  0.6037,
#  0.6037,
#  0.5878,
#  0.5716,
#  0.5878,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.5878,
#  0.5878,
#  0.5878,
#  0.5878,
#  0.5798,
#  0.5878,
#  0.5878,
#  0.5878,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.5716,
#  0.5634,
#  0.5634,
#  0.5476,
#  0.5233,
#  0.5476,
#  0.5476,
#  0.5476,
#  0.5233,
#  0.5313,
#  0.5393,
#  0.5393,
#  0.5393,
#  0.5313,
#  0.5154,
#  0.5074,
#  0.5074,
#  0.5233,
#  0.5154,
#  0.5074,
#  0.49892,
#  0.48318999999999995,
#  0.45902,
#  0.4669,
#  0.45902,
#  0.47508999999999996,
#  0.49111000000000005,
#  0.49892,
#  0.5233,
#  0.5233,
#  0.5313,
#  0.5233,
#  0.5313,
#  0.5313,
#  0.5393,
#  0.5393,
#  0.5313,
#  0.5313,
#  0.5154,
#  0.5154,
#  0.5233,
#  0.5233,
#  0.5313,
#  0.5233,
#  0.5233,
#  0.5313,
#  0.5313,
#  0.5393,
#  0.5555,
#  0.5476,
#  0.5555,
#  0.5555,
#  0.5476,
#  0.5476,
#  0.5476,
#  0.5476,
#  0.5555,
#  0.5476,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5716,
#  0.5798,
#  0.5798,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5716,
#  0.5555,
#  0.5476,
#  0.5476,
#  0.5555,
#  0.5634,
#  0.5555,
#  0.5634,
#  0.5555,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5555,
#  0.5476,
#  0.5393,
#  0.5393,
#  0.5313,
#  0.5154,
#  0.5313,
#  0.5313,
#  0.5393,
#  0.5393,
#  0.5555,
#  0.5634,
#  0.5634,
#  0.5634,
#  0.5555,
#  0.5476,
#  0.5476,
#  0.5634,
#  0.5555,
#  0.5555,
#  0.5555,
#  0.5476,
#  0.5393,
#  0.5313,
#  0.5555,
#  0.5476,
#  0.5555,
#  0.5555,
#  0.5716,
#  0.5634,
#  0.5716,
#  0.5798,
#  0.5798,
#  0.5798,
#  0.5957,
#  0.5957,
#  0.5957,
#  0.6037,
#  0.6037,
#  0.6037,
#  0.6037,
#  0.6037,
#  0.6122,
#  0.6277,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6277,
#  0.6362,
#  0.6277,
#  0.6362,
#  0.6277,
#  0.6277,
#  0.6442,
#  0.6362,
#  0.6442,
#  0.6362,
#  0.6277,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6442,
#  0.6442,
#  0.6362,
#  0.6362,
#  0.6442,
#  0.6442,
#  0.6362,
#  0.652,
#  0.652,
#  0.6602,
#  0.6602,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6442,
#  0.652,
#  0.652,
#  0.6442,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.6602,
#  0.652,
#  0.6602,
#  0.652,
#  0.6362,
#  0.6277,
#  0.6362,
#  0.6277,
#  0.6201,
#  0.6201,
#  0.6037,
#  0.6122,
#  0.6122,
#  0.6037,
#  0.6122,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6122,
#  0.6122,
#  0.6037,
#  0.6037,
#  0.6122,
#  0.6122,
#  0.6122,
#  0.6122,
#  0.6122,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6201,
#  0.6122,
#  0.6201,
#  0.6201,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6362,
#  0.6442,
#  0.6442,
#  0.652,
#  0.6442,
#  0.6442,
#  0.652,
#  0.6683,
#  0.6683,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6683,
#  0.6762,
#  0.6683,
#  0.6762,
#  0.6762,
#  0.6843,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6762,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.7005,
#  0.6924,
#  0.6924,
#  0.6843,
#  0.6843,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6762,
#  0.6762,
#  0.6602,
#  0.6683,
#  0.6683,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6602,
#  0.652,
#  0.6602,
#  0.652,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6602,
#  0.652,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.652,
#  0.6442,
#  0.6362,
#  0.6442,
#  0.6362,
#  0.6442,
#  0.6442,
#  0.652,
#  0.652,
#  0.652,
#  0.652,
#  0.6602,
#  0.6683,
#  0.6602,
#  0.6602,
#  0.6683,
#  0.6683,
#  0.6762,
#  0.6843,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6683,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.6843,
#  0.6843,
#  0.6843,
#  0.6924,
#  0.6843,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6602,
#  0.6683,
#  0.6602,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.652,
#  0.652,
#  0.652,
#  0.6442,
#  0.652,
#  0.652,
#  0.652,
#  0.6683,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6683,
#  0.6762,
#  0.6762,
#  0.6683,
#  0.6924,
#  0.7085,
#  0.6924,
#  0.7005,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6683,
#  0.6762,
#  0.6843,
#  0.6762,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.652,
#  0.652,
#  0.6602,
#  0.652,
#  0.652,
#  0.6602,
#  0.6602,
#  0.6843,
#  0.6924,
#  0.6843,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.7005,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7005,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.7005,
#  0.7005,
#  0.7166,
#  0.7247,
#  0.7247,
#  0.7166,
#  0.7085,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7247,
#  0.7326,
#  0.7408,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7408,
#  0.7488,
#  0.7408,
#  0.7408,
#  0.7326,
#  0.7326,
#  0.7247,
#  0.7326,
#  0.7085,
#  0.7085,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7326,
#  0.7408,
#  0.7488,
#  0.7488,
#  0.7488,
#  0.7488,
#  0.7488,
#  0.7408,
#  0.7408,
#  0.7326,
#  0.7247,
#  0.7166,
#  0.7085,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7408,
#  0.7326,
#  0.7408,
#  0.7326,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7166,
#  0.7085,
#  0.6924,
#  0.7005,
#  0.6924,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.6843,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.7005,
#  0.6843,
#  0.6843,
#  0.6924,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6762,
#  0.6683,
#  0.6683,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6602,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6683,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6602,
#  0.6683,
#  0.6762,
#  0.6843,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.7005,
#  0.7005,
#  0.7085,
#  0.7085,
#  0.7085,
#  0.7166,
#  0.7085,
#  0.7085,
#  0.6924,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.6924,
#  0.6843,
#  0.6924,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6843,
#  0.6762,
#  0.6843,
#  0.6924,
#  0.6924,
#  0.7005,
#  0.7005,
#  0.6924,
#  0.6924,
#  0.6843,
#  0.6924,
#  0.7005,
#  0.7005,
#  0.7085,
#  0.7166,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7326,
#  0.7408,
#  0.7408,
#  0.7488,
#  0.7488,
#  0.7408,
#  0.7408,
#  0.7488,
#  0.7488,
#  0.7408,
#  0.7408,
#  0.7408,
#  0.7326,
#  0.7247,
#  0.7247,
#  0.7247,
#  0.7166,
#  0.7247,
#  0.7247,
#  0.7326,
#  0.7326,
#  0.7408,
#  0.7408,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7247,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7408,
#  0.7408,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7326,
#  0.7408,
#  0.7488,
#  0.7488,
#  0.7568,
#  0.7651,
#  0.7651,
#  0.7729,
#  0.7807,
#  0.7729,
#  0.7568,
#  0.7568,
#  0.7651,
#  0.7651,
#  0.7729,
#  0.7729,
#  0.7651,
#  0.7568,
#  0.7568,
#  0.7488,
#  0.7488,
#  0.7488,
#  0.7488,
#  0.7568,
#  0.7651,
#  0.7651,
#  0.7651,
#  0.7568,
#  0.7568,
#  0.7488,
#  0.7568,
#  0.7729,
#  0.7651,
#  0.7729,
#  0.7807,
#  0.7891,
#  0.7891,
#  0.7891,
#  0.797,
#  0.8131,
#  0.8131,
#  0.8131,
#  0.805,
#  0.8131,
#  0.805,
#  0.8131,
#  0.8131,
#  0.8131,
#  0.8131,
#  0.8131,
#  0.8212,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8212,
#  0.8212,
#  0.8212,
#  0.8131,
#  0.797,
#  0.805,
#  0.797,
#  0.797,
#  0.805,
#  0.8131,
#  0.805,
#  0.805,
#  0.8131,
#  0.8293,
#  0.8293,
#  0.8212,
#  0.8373,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8373,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8615,
#  0.8615,
#  0.8615,
#  0.8293,
#  0.8212,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8293,
#  0.8373,
#  0.8455,
#  0.8455,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8615,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8615,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8455,
#  0.8615,
#  0.8694,
#  0.8776,
#  0.8776,
#  0.8858,
#  0.8858,
#  0.8776,
#  0.8776,
#  0.8858,
#  0.8858,
#  0.8858,
#  0.8858,
#  0.8694,
#  0.8694,
#  0.8694,
#  0.8615,
#  0.8615,
#  0.8455,
#  0.8455,
#  0.8535,
#  0.8535,
#  0.8615,
#  0.8535,
#  0.8455,
#  0.8373,
#  0.8373,
#  0.8373,
#  0.8212,
#  0.8131,
#  0.805,
#  0.805,
#  0.797,
#  0.805,
#  0.8131,
#  0.8131,
#  0.805,
#  0.8131,
#  0.8131,
#  0.8131,
#  0.7891,
#  0.7729,
#  0.7651,
#  0.7891,
#  0.797,
#  0.805,
#  0.8212,
#  0.8212,
#  0.8212,
#  0.8373,
#  0.8455,
#  0.8293,
#  0.8293,
#  0.8373,
#  0.8293,
#  0.8293,
#  0.8131,
#  0.805,
#  0.805,
#  0.8131,
#  0.8212,
#  0.8131,
#  0.8131,
#  0.8293,
#  0.8373,
#  0.8373,
#  0.8373,
#  0.8535,
#  0.8535,
#  0.8535,
#  0.8615,
#  0.8455,
#  0.8535,
#  0.8694,
#  0.8776,
#  0.8694,
#  0.8535,
#  0.8615,
#  0.8615,
#  0.8535,
#  0.8455,
#  0.8455,
#  0.8455,
#  0.8615,
#  0.8776,
#  0.8694,
#  0.8858,
#  0.8694,
#  0.8694,
#  0.8858,
#  0.8938,
#  0.8938,
#  0.9015,
#  0.9015,
#  0.9096,
#  0.9259999999999999,
#  0.9259999999999999,
#  0.9339,
#  0.9339,
#  0.9339,
#  0.9419,
#  0.9419,
#  0.95,
#  0.9339,
#  0.958,
#  0.9903,
#  0.9822,
#  0.9822,
#  0.9742,
#  0.9742,
#  0.9662,
#  0.9822,
#  0.9903,
#  0.9822,
#  0.9822,
#  0.9822,
#  0.9822,
#  0.9742,
#  0.958,
#  0.958,
#  0.9662,
#  0.9662,
#  0.9742,
#  0.9822,
#  0.9822,
#  0.9742,
#  0.9822,
#  0.9822,
#  0.9822,
#  0.9822,
#  0.9742,
#  0.9742,
#  0.9742,
#  0.9742,
#  0.958,
#  0.958,
#  0.9662,
#  0.9742,
#  0.9742,
#  0.958,
#  0.9662,
#  0.9662,
#  0.958,
#  0.958,
#  0.9419,
#  0.95,
#  0.9419,
#  0.95,
#  0.95,
#  0.95,
#  0.95,
#  0.958,
#  0.95,
#  0.95,
#  0.95,
#  0.95,
#  0.9419,
#  0.9419,
#  0.9419,
#  0.95,
#  0.95,
#  0.95,
#  0.9419,
#  0.9419,
#  ...]

# %%
Inprice = np.log(prices)

# %%
Inprice
# Out:
# array([-0.46569293, -0.47787452, -0.47787452, ...,  3.00617753,
#         2.99773028,  2.99473177])

# %%
plt.plot(Inprice)
plt.show()

# %%
acf_1 = acf(Inprice)[1:14000]
test_df = pandas.DataFrame([acf_1]).T
test_df.colums = ['Autocorrelation']
test_df.index += 1
test_df.plot(kind = 'bar')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pacf_1 = acf(Inprice)[1:14000]
test_df = pandas.DataFrame([pacf_1]).T
test_df.colums = ['Partial Autocorrelation']
test_df.index += 1
test_df.plot(kind = 'bar')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until
